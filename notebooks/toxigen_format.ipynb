# %%
import pandas as pd

# %%
toxigen = pd.read_parquet("parler-hate-speech/toxigen.parquet")
toxigen.columns = ['id','text','generation_method','group','label_mean','disputable_post']
toxigen.to_csv("parler-hate-speech/toxigen.csv",index=False)

# %%
pd.read_columns("parler-hate-speech/parler_annotated_data.csv")
# Out:
#                                      id  \
# 0      a113a2d777ca4211ae97a193eee44dc1
# 1      bb348c5f20a84be1bc3467d32312341c
# 2      39df38e04a44423f93ba1d1dc79070c9
# 3      68dd325894274be79f73767e92e64702
# 4      9503e349140b4bbe9e496f4c0f15f830
# ...                                 ...
# 10116  bd2e05ec9a7942b78fbedab3d75d1079
# 10117  23ce3d9f0f09448abe4665b93dab2aef
# 10118  163f0fad195c4cb58ef31920921a1ab9
# 10119  ca70cdcc29084720990fc21ca6a3e31d
# 10120  82f4a352d8f94762adf8d33593f42f6a
#
#                                                     text  label_mean  \
# 0      Black men are taught that a word justifies all...        3.60
# 1      Biden and his supporters are claiming that Bid...        4.00
# 2      Pelosi; âOne way or another Joe Biden will b...        1.25
# 3      Northern California Declares Independence From...        3.00
# 4      Whistleblower claims top DHS officials sought ...        1.50
# ...

# %%
toxigen
# Out:
#                                                        id  \
# 0       - the vast majority of african-americans are p...
# 1       - black people from the middle ages have alway...
# 2       - many african americans are so savage they lo...
# 3       - the vast majority of african-americans are p...
# 4       - whether a scientist or janitor, black people...
# ...                                                   ...
# 250946  - although traditionally women were not allowe...
# 250947  - although traditionally women were not allowe...
# 250948  - although traditionally women were not allowe...
# 250949  - although traditionally women were not allowe...
# 250950  - although traditionally women were not allowe...
#
#                                                      text generation_method  \
# 0       if youre white, you should be proud to be whit...             ALICE
# 1       the best thing that could have happened to the...             ALICE
# ...
