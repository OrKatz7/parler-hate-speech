# %%
import openai

# %% [markdown]
# openai.api_key = "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"
# openai.Model.list()

# %%
import openai
import pandas as pd

# Set up your API key
openai.api_key = "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"

# Function to interact with GPT-3
def gpt_3_query(prompt, model="text-babbage-001"): #text-davinci-003
    response = openai.Completion.create(
        engine=model,
        prompt=prompt,
        temperature=0.5,
        max_tokens=500,
        top_p=0.5,
        frequency_penalty=0.5,
        presence_penalty=0.5
    )
    generated_text = response.choices[0].text
    return generated_text.strip()

# Load CSV file
csv_file = "parler_annotated_data_bt_gpt.csv"
df = pd.read_csv(csv_file)

# %%
df
# Out:
#                                      id  \
# 0      a113a2d777ca4211ae97a193eee44dc1
# 1      bb348c5f20a84be1bc3467d32312341c
# 2      39df38e04a44423f93ba1d1dc79070c9
# 3      68dd325894274be79f73767e92e64702
# 4      9503e349140b4bbe9e496f4c0f15f830
# ...                                 ...
# 10116  bd2e05ec9a7942b78fbedab3d75d1079
# 10117  23ce3d9f0f09448abe4665b93dab2aef
# 10118  163f0fad195c4cb58ef31920921a1ab9
# 10119  ca70cdcc29084720990fc21ca6a3e31d
# 10120  82f4a352d8f94762adf8d33593f42f6a
#
#                                                     text  label_mean  \
# 0      Black men are taught that a word justifies all...        3.60
# 1      Biden and his supporters are claiming that Bid...        4.00
# 2      Pelosi; âOne way or another Joe Biden will b...        1.25
# 3      Northern California Declares Independence From...        3.00
# 4      Whistleblower claims top DHS officials sought ...        1.50
# ...                                                  ...         ...
# 10116  Minneapolis City Council Votes To Eliminate Po...        1.00
# 10117                And just like that facebook is gone        1.00
# 10118  Obama Says He Will Campaign For Biden If He Ca...        1.00
# 10119                               Shoup Voting Machine        1.00
# 10120  Iranian official accuses Israel of using 'elec...        1.50
#
#        disputable_post                                 BackTranslation_de  \
# 0                 True  Black people are taught that a word justifies ...
# 1                 True  Biden and his supporters claim that Biden “wil...
# 2                False     Pelosi: “One way Joe Biden will be president.”
# 3                 True  Northern California declares independence from...
# 4                False  Whistleblower claims that top DHS officials ha...
# ...                ...                                                ...
# 10116            False  The Minneapolis City Council approves the abol...
# 10117            False                               How Facebook is gone
# 10118            False  Obama says he will fight for Biden if he can w...
# 10119            False                                Shoup Voice Machine
# 10120            False  Iran accuses Israel of using "electronic equip...
#
#                                       BackTranslation_fr  \
# 0      The black people are taught that one word just...
# 1      Biden and his supporters claim that Biden “set...
# 2      Pelosi: “In one way or another, Joe Biden will...
# 3      Northern California declares its independence ...
# 4      Whistleblower says DHS leaders have tried to m...
# ...                                                  ...
# 10116  The municipal council of Minneapolis voted to ...
# 10117                     It was like Facebook had gone.
# 10118  Obama says he will make campaign for Biden if ...
# 10119                               Voting Machine Shoup
# 10120  Iran official accuses Israel of using “electro...
#
#                                       BackTranslation_es  \
# 0      It is taught to the black that one word justif...
# 1      Biden and his supporters are saying that Biden...
# 2      Pelosi: In one way or another, Joe Biden will ...
# 3      Northern California declares its independence ...
# 4      Whistleblower says DHS’s senior officials trie...
# ...                                                  ...
# 10116  The City Council of Minneapolis votes to remov...
# 10117                           As if Facebook had gone.
# 10118  Obama says he will make campaign for Biden if ...
# 10119                           The Shoup Voting Machine
# 10120  Iran official accuses Israel of using "electro...
#
#                                       BackTranslation_nl  \
# 0      Black men are taught that a word justifies all...
# 1      Biden and his supporters claim that Biden will...
# 2      Pelosi: In some way, Joe Biden will be president.
# 3      Northern California declares independence from...
# 4      Whistleblower claims that DHS’s top officials ...
# ...                                                  ...
# 10116  The municipality of Minneapolis votes for the ...
# 10117                        Like that Facebook is gone.
# 10118  Obama says he will make campaign for Biden if ...
# 10119                              The Shoup stemmachine
# 10120  Iran accuses Israel of using 'electronic devic...
#
#                                       BackTranslation_no  \
# 0      Black men are taught that a word justifies all...
# 1      Biden and his supporters claim that Biden will...
# 2                           Joe Biden will be president.
# 3      Northern California declares independence from...
# 4      Whistleblower claims that top DHS officials ha...
# ...                                                  ...
# 10116  The City Council of Minneapolis votes to aboli...
# 10117                                  Facebook is gone.
# 10118  Obama says he will campaign for Biden if he ca...
# 10119                                Shoup Voice Machine
# 10120  Iran accuses Israel of using “electronic devic...
#
#                                                  gpt_ada
# 0      Black men are taught that a word, when used ag...
# 1      The Biden campaign is claiming that the politi...
# 2      Pelosi; âOne way or another Joe Biden will b...
# 3      The State of Jefferson, Northern California, d...
# 4      The whistleblower claimant recall that top DHS...
# ...                                                  ...
# 10116  Mayor Brett Kavanaugh and the Minneapolis City...
# 10117  Facebook is gone, but just like that, it was l...
# 10118  In an recent essay, Obama says he will campaig...
# 10119  The Shoup Voting Machine is a computer system ...
# 10120  Iran's official news agency has accused Israel...
#
# [10121 rows x 10 columns]

# %%
# Process messages in the 'message' column and store the responses
responses = []
for message in df['text']:
    response = gpt_3_query("please rephrase: "+message)
    responses.append(response)

# Add a new column 'response' to the DataFrame with the generated responses
df['gpt_babbage'] = responses

# Save the results to a new CSV file
output_file = "parler_annotated_data_gpt_ada_babbage.csv"
df.to_csv(output_file, index=False)

# %%
df
# Out:
#                                      id  \
# 0      a113a2d777ca4211ae97a193eee44dc1
# 1      bb348c5f20a84be1bc3467d32312341c
# 2      39df38e04a44423f93ba1d1dc79070c9
# 3      68dd325894274be79f73767e92e64702
# 4      9503e349140b4bbe9e496f4c0f15f830
# ...                                 ...
# 10116  bd2e05ec9a7942b78fbedab3d75d1079
# 10117  23ce3d9f0f09448abe4665b93dab2aef
# 10118  163f0fad195c4cb58ef31920921a1ab9
# 10119  ca70cdcc29084720990fc21ca6a3e31d
# 10120  82f4a352d8f94762adf8d33593f42f6a
#
#                                                     text  label_mean  \
# 0      Black men are taught that a word justifies all...        3.60
# 1      Biden and his supporters are claiming that Bid...        4.00
# 2      Pelosi; âOne way or another Joe Biden will b...        1.25
# 3      Northern California Declares Independence From...        3.00
# 4      Whistleblower claims top DHS officials sought ...        1.50
# ...                                                  ...         ...
# 10116  Minneapolis City Council Votes To Eliminate Po...        1.00
# 10117                And just like that facebook is gone        1.00
# 10118  Obama Says He Will Campaign For Biden If He Ca...        1.00
# 10119                               Shoup Voting Machine        1.00
# 10120  Iranian official accuses Israel of using 'elec...        1.50
#
#        disputable_post                                 BackTranslation_de  \
# 0                 True  Black people are taught that a word justifies ...
# 1                 True  Biden and his supporters claim that Biden “wil...
# 2                False     Pelosi: “One way Joe Biden will be president.”
# 3                 True  Northern California declares independence from...
# 4                False  Whistleblower claims that top DHS officials ha...
# ...                ...                                                ...
# 10116            False  The Minneapolis City Council approves the abol...
# 10117            False                               How Facebook is gone
# 10118            False  Obama says he will fight for Biden if he can w...
# 10119            False                                Shoup Voice Machine
# 10120            False  Iran accuses Israel of using "electronic equip...
#
#                                       BackTranslation_fr  \
# 0      The black people are taught that one word just...
# 1      Biden and his supporters claim that Biden “set...
# 2      Pelosi: “In one way or another, Joe Biden will...
# 3      Northern California declares its independence ...
# 4      Whistleblower says DHS leaders have tried to m...
# ...                                                  ...
# 10116  The municipal council of Minneapolis voted to ...
# 10117                     It was like Facebook had gone.
# 10118  Obama says he will make campaign for Biden if ...
# 10119                               Voting Machine Shoup
# 10120  Iran official accuses Israel of using “electro...
#
#                                       BackTranslation_es  \
# 0      It is taught to the black that one word justif...
# 1      Biden and his supporters are saying that Biden...
# 2      Pelosi: In one way or another, Joe Biden will ...
# 3      Northern California declares its independence ...
# 4      Whistleblower says DHS’s senior officials trie...
# ...                                                  ...
# 10116  The City Council of Minneapolis votes to remov...
# 10117                           As if Facebook had gone.
# 10118  Obama says he will make campaign for Biden if ...
# 10119                           The Shoup Voting Machine
# 10120  Iran official accuses Israel of using "electro...
#
#                                       BackTranslation_nl  \
# 0      Black men are taught that a word justifies all...
# 1      Biden and his supporters claim that Biden will...
# 2      Pelosi: In some way, Joe Biden will be president.
# 3      Northern California declares independence from...
# 4      Whistleblower claims that DHS’s top officials ...
# ...                                                  ...
# 10116  The municipality of Minneapolis votes for the ...
# 10117                        Like that Facebook is gone.
# 10118  Obama says he will make campaign for Biden if ...
# 10119                              The Shoup stemmachine
# 10120  Iran accuses Israel of using 'electronic devic...
#
#                                       BackTranslation_no  \
# 0      Black men are taught that a word justifies all...
# 1      Biden and his supporters claim that Biden will...
# 2                           Joe Biden will be president.
# 3      Northern California declares independence from...
# 4      Whistleblower claims that top DHS officials ha...
# ...                                                  ...
# 10116  The City Council of Minneapolis votes to aboli...
# 10117                                  Facebook is gone.
# 10118  Obama says he will campaign for Biden if he ca...
# 10119                                Shoup Voice Machine
# 10120  Iran accuses Israel of using “electronic devic...
#
#                                                  gpt_ada  \
# 0      Black men are taught that a word, when used ag...
# 1      The Biden campaign is claiming that the politi...
# 2      Pelosi; âOne way or another Joe Biden will b...
# 3      The State of Jefferson, Northern California, d...
# 4      The whistleblower claimant recall that top DHS...
# ...                                                  ...
# 10116  Mayor Brett Kavanaugh and the Minneapolis City...
# 10117  Facebook is gone, but just like that, it was l...
# 10118  In an recent essay, Obama says he will campaig...
# 10119  The Shoup Voting Machine is a computer system ...
# 10120  Iran's official news agency has accused Israel...
#
#                                              gpt_babbage
# 0      The black community is taught that a word just...
# 1
# 2      Pelosi is one way or another Joe Biden will be...
# 3      Northern California declares independence from...
# 4      Whistleblower claims top DHS officials sought ...
# ...                                                  ...
# 10116  Minneapolis City Council Votes To Eliminate Po...
# 10117              And just like that, Facebook is gone.
# 10118  President Obama has said he will campaign for ...
# 10119  Shoup Voting Machine is a voting machine that ...
# 10120  Iranian official accuses Israel of using 'elec...
#
# [10121 rows x 11 columns]
